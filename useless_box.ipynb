# %% [markdown]
# <h1><center> project: ub </center></h1>
# <br>
# <br>
# <br>
#
# Last Modified: By Daniel Baur on 23rd February 2021
#
# This notebook is meant to provide documentation on the ``ub`` project. Its ambition is to set up a XXX.
#
#
#
# <br>
# <br>
#
# ### Table of Contents
#
# 1. **[Resources](#1.-Resources)**<br>
#
#
# 2. **[Stuff](#2.-Stuff)**<br>
#     2.1 [Stuff](#2.1-Stuff)<br>
#     2.2 [Stuff](#2.2-Stuff)<br>
#     2.3 [Stuff](#2.3-Stuff)
#
#
# <br>
# <br>
# <br>
# <br>
# <br>
#
#
# # 1. Resources
#
# <br>
# <br>
#
# * The following instructions for the useless box build essentially follow [Daniele Tartaglia's
# ](https://www.youtube.com/channel/UCwMjr5HocO6S363x_-jzsmA) YouTube video [`DON'T TOUCH BOX !!! - Useless box with arduino - DIY`](https://www.youtube.com/watch?v=5BRDxsO_TuQ) and [written instructions](https://www.labdomotic.com/2017/10/24/youtube-useless-box-fai-da-te/). I adapted his build to be efficiently reproducible within the microcontroller exercises of the `Einführung in die moderne Digitalelektronik` lecture:
#   * Instead of assembling a wooden box, a 3D-printed one is used.
#   * Instead of utilizing a "costly" arduino board a ATMEGA microcontroller is utilized in a dead bug installation.
# * [YouTube video by GreatScott!: Electronic Basics #6: Standalone Arduino Circuit](https://www.youtube.com/watch?v=J3DYgzRvLT8)
# * [YouTube video by DroneBot Workshop: Arduino Uno to ATmega328 - Shrinking your Arduino Projects](https://www.youtube.com/watch?v=Sww1mek5rHU)
# * [flash Arduino Bootloader](https://praxistipps.chip.de/arduino-bootloader-neu-flashen-so-gehts_101452)
# <br>
# <br>
# <br>
# <br>
# <br>
#
# # 2. Parts List
#
# <br>
# <br>
#
# Find below a list of the required components along with the corresponding [Conrad links]().
#
# * [sliding switch](https://www.conrad.de/de/p/tru-components-css-1202-schiebeschalter-50-v-dc-0-3-a-1-x-aus-ein-1-st-1569017.html) (0.62€)
# * [toggle switch](https://www.conrad.de/de/p/tru-components-tc-r13-2-05-kippschalter-250-v-ac-1-5-a-1-x-aus-ein-rastend-1-st-1587664.html) (1.13€)
# * [compartment for four AA batteries](https://www.conrad.de/de/p/tru-components-sbh341-1a-batteriehalter-4x-mignon-aa-kabel-1672572.html) (1.67€)
# * [SG90 servo motor (1.8 kg*cm @6V)](https://www.conrad.de/de/p/makerfactory-mf-6402123-motor-2134041.html) (3.55€)
# * [SG5010 servo motor (6.5 kg*cm @6V, wrong image in Conrad webshop)](https://www.conrad.de/de/p/adafruit-155-servomotor-1516599.html) (15.99€)
# * [ATMEGA328P microcontroller](https://www.conrad.de/de/p/microchip-technology-atmega328p-pu-embedded-mikrocontroller-pdip-28-8-bit-20-mhz-anzahl-i-o-23-155197.html) (2.16€)
# * [16MHz quartz resonator](https://www.conrad.de/de/p/euroquartz-quarzkristall-quarz-hc49-us-hc49-4h-16-000-mhz-18-pf-l-x-b-x-h-3-68-x-10-26-x-3-5-mm-1-st-155145.html) (0.54€)
# * [2x 22pF capacitors](https://www.conrad.de/de/p/tru-components-tc-k22pf500v-keramik-kondensator-tht-22-pf-500-v-5-1-st-1589526.html) (2x 0.075€)
# * set of 3D-printed components: box, lid, lever (`.ipt`, `.stp` and `.stl` files in this repository)
#
# Neglecting the costs for the 3D-print the items above add up to 24.71€
#
# <br>
# <br>
# <br>
# <br>
# <br>
#
# # 3. Instructions
#
# <br>
# <br>
#
# ### Hardware
#
# <br>
#
# Find below the circuit of the project:
#
# ![daniele_tartaglia__circuit_scheme_1.png](attachment:daniele_tartaglia__circuit_scheme_1.png)
#
# <br>
# <br>
#
# ### Software
#
#
#
# <br>
# <br>
# <br>
# <br>
# <br>
#
# # 4. Further Improvements
#
# <br>
# <br>
#
# * sacrifice toy plushy for decoration
#
# * use rechargable batteries and implement charging circuit
#
# * replace jumper wire connections with breadboard, grid plate or even PCB
#
# <br>
# <br>
# <br>
# <br>
# <br>
